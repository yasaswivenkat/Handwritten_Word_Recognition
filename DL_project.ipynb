# %%
# !pip install kagglehub scikit-learn tensorflow

# Step 1: Importing required libraries
import os
from google.colab import userdata
from google.colab import auth
from google.colab import files
from google.colab import drive
import kagglehub

# Step 2: Loading Kaggle credentials
try:
    os.environ["KAGGLE_USERNAME"] = userdata.get('KAGGLE_USERNAME')
    os.environ["KAGGLE_KEY"] = userdata.get('KAGGLE_KEY')
except Exception:
    print("Kaggle credentials not found in Colab secrets!!")

#Step 3: Downloading IAM dataset from kaggle
try:
    print("Downloading and unzipping dataset...")
    path = kagglehub.dataset_download("naderabdalghani/iam-handwritten-forms-dataset")
    # !kaggle datasets download -d naderabdalghani/iam-handwritten-forms-dataset -p /content
    # !unzip -o /content/iam-handwritten-forms-dataset.zip -d /content/data
    print("Dataset unzipped to /content/data")
except Exception as e:
    print(f"Could not automatically download/unzip: {e}")
    print("Assuming dataset is manually placed,try with adjusting path.")
    path = "/content/data" # Default path
print("Path to dataset files:", path)
try:
    print("Files in dataset root:", os.listdir(path)[:5])
except FileNotFoundError:
    print("Warning: /content/data not found. Please ensure that dataset is unzipped or path is adjusted correctly")

# Main Code :
import os
import glob
import random
import xml.etree.ElementTree as ET
from collections import Counter
import numpy as np
import cv2
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers, models
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, ConfusionMatrixDisplay, classification_report

# ---------------------------
ROOT_DIR=os.path.join("/content", "data")
MAX_SAMPLES=2000
IMG_H, IMG_W=64,256
TOP_K_WORDS=20
BATCH_SIZE=32
EPOCHS=6
RANDOM_SEED=42
TRANSFER_MODELS=['VGG16','ResNet50V2','EfficientNetB0'] # 3 pre-trained models

tf.random.set_seed(RANDOM_SEED)
np.random.seed(RANDOM_SEED)
random.seed(RANDOM_SEED)

# ---------------------------
def find_files(root):
    matches = []
    for ext in ["png", "jpg", "tif", "tiff", "jpeg"]:
        matches.extend(glob.glob(os.path.join(root, "**", f"*.{ext}"), recursive=True))
    xmls = glob.glob(os.path.join(root, "**", "*.xml"), recursive=True)
    return matches, xmls

all_images, all_xmls = find_files(ROOT_DIR)
print("-" * 50)
print("Using ROOT_DIR =", ROOT_DIR)
print("Found images:", len(all_images), "Found xmls:", len(all_xmls))

if len(all_images) == 0:
    print("No images found!!")
    all_images, all_xmls = find_files("/content")
    ROOT_DIR = "/content"
    print(f"Found {len(all_images)} images in /content.")
    if len(all_images) == 0:
        raise FileNotFoundError("No images found. Please verify dataset unzipped and path (ROOT_DIR).")

# ---------------------------
# Extract labels
pairs = []
def parse_xml_for_pairs(xml_paths, img_root):
    extracted = []
    for xp in xml_paths:
        try:
            tree = ET.parse(xp)
        except Exception:
            continue
        root = tree.getroot()
        for word_tag in root.iter():
            if word_tag.tag.lower().endswith("word"):
                text = word_tag.attrib.get('text') or word_tag.attrib.get('content') \
                        or word_tag.attrib.get('name') or word_tag.attrib.get('label')
                if text is None:
                    text = (word_tag.text or "").strip()
                file_ref = word_tag.attrib.get('file') or word_tag.attrib.get('image')
                if file_ref:
                    full = os.path.join(img_root, file_ref) if not os.path.isabs(file_ref) else file_ref
                else:
                    full = None
                # Checking for image existence
                if text and full:
                    if not os.path.exists(full):
                         parts = os.path.dirname(xp).split(os.sep)
                         if len(parts) >= 2:
                             sub_dir_guess = os.sep.join(parts[:-2] + ["words", full])
                             if os.path.exists(sub_dir_guess):
                                full = sub_dir_guess
                    if os.path.exists(full):
                        extracted.append((full, text))
    print(f"Extracted {len(extracted)} pairs from XMLs.")
    return extracted

if all_xmls:
    print("Attempting to parse XMLs for labels...")
    xml_pairs = parse_xml_for_pairs(all_xmls, ROOT_DIR)
    print("Pairs recovered from xml:", len(xml_pairs))
    pairs.extend(xml_pairs)
if not pairs:
    print("Falling back to filename heuristics for labels.")
    for p in all_images:
        fname = os.path.basename(p)
        label = None
        for sep in ["-", "_", "."]:
            parts = fname.split(sep)
            if len(parts) >= 2:
                candidate = parts[0]
                if any(c.isalpha() for c in candidate):
                    label = candidate.lower()
                    break
        if label is None:
            label = os.path.splitext(fname)[0].lower()
        pairs.append((p, label))
    print("Pairs extracted:", len(pairs))
random.shuffle(pairs)
pairs = pairs[:MAX_SAMPLES]
print("Total pairs used after initial filtering and trimming:", len(pairs))

# ---------------------------
# Building word frequency and filter
words = [w for (_, w) in pairs]
freq = Counter(words)
top_words = [w for w, _ in freq.most_common(TOP_K_WORDS)]
print(f"Top {TOP_K_WORDS} words: {top_words}")

pairs = [(p, w) for (p, w) in pairs if w in top_words]
print("Pairs after filtering for top K words:", len(pairs))

if len(pairs) == 0:
    raise ValueError("No pairs left after filtering top K words.")

# ---------------------------
# Loading image arrays and Preprocessing
def load_and_preprocess(pairs, img_h=IMG_H, img_w=IMG_W):
    X, Y = [], []
    for p, w in pairs:
        try:
            img = cv2.imread(p, cv2.IMREAD_GRAYSCALE)
            if img is None:
                continue
            # Padding
            img = cv2.resize(img, (img_w, img_h))
            img = img.astype(np.float32) / 255.0
            X.append(img)
            Y.append(w)
        except Exception:
            continue
    return np.array(X), np.array(Y)
X, Y = load_and_preprocess(pairs)
print("-" * 50)
print("Loaded images shape:", X.shape)
if len(X) == 0:
    raise ValueError("No images loaded after preprocessing.")
Xc = np.expand_dims(X, -1)
le_words = LabelEncoder()
y_cls = le_words.fit_transform(Y)
num_classes = len(le_words.classes_)
print("Number of classes:", num_classes)
class_names = le_words.classes_
X_train, X_test, y_train, y_test = train_test_split(Xc, y_cls, test_size=0.2, random_state=RANDOM_SEED, stratify=y_cls)
print("Train/Test shapes (Grayscale):", X_train.shape, X_test.shape)

# ---------------------------
#  For Transfer Learning models: gray → 3-channel
def gray_to_3ch(Xgray):
    return np.repeat(Xgray, 3, axis=-1)
X_train_3 = gray_to_3ch(X_train)
X_test_3  = gray_to_3ch(X_test)
print("Train/Test shapes (3-Channel):", X_train_3.shape, X_test_3.shape)
results = {}

# ---------------------------
# Model 1: CNN Classifier
print("\n" + "=" * 50)
print("Training Model 1: CNN Classifier")
print("=" * 50)

def build_cnn_classifier(input_shape, n_classes):
    inp = layers.Input(shape=input_shape)
    x = layers.Conv2D(32, 3, activation='relu', padding='same')(inp)
    x = layers.MaxPool2D(2)(x)
    x = layers.Conv2D(64, 3, activation='relu', padding='same')(x)
    x = layers.MaxPool2D(2)(x)
    x = layers.Conv2D(128, 3, activation='relu', padding='same')(x)
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dense(128, activation='relu')(x)
    out = layers.Dense(n_classes, activation='softmax')(x)
    m = models.Model(inp, out, name='cnn_classifier')
    m.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return m

cnn_model = build_cnn_classifier((IMG_H, IMG_W, 1), num_classes)
cnn_model.summary()
history_cnn = cnn_model.fit(X_train, y_train, validation_data=(X_test, y_test),
                            epochs=EPOCHS, batch_size=BATCH_SIZE, verbose=2)

# ---------------------------
# CNN → LSTM and GRU models

def cnn_feature_extractor(input_shape):
    inp = layers.Input(shape=input_shape)
    x = layers.Conv2D(32, 3, activation='relu', padding='same')(inp)
    x = layers.MaxPool2D((2, 1))(x)
    x = layers.Conv2D(64, 3, activation='relu', padding='same')(x)
    x = layers.MaxPool2D((2, 1))(x)
    return models.Model(inp, x, name='cnn_feat')

feat_extractor = cnn_feature_extractor((IMG_H, IMG_W, 1))

def X_to_seq_feats(model_feat, X):
    print("Extracting features...")
    feat = model_feat.predict(X, batch_size=BATCH_SIZE, verbose=0)
    n, h, w, c = feat.shape
    return feat.reshape((n, w, h * c))

X_train_seq = X_to_seq_feats(feat_extractor, X_train)
X_test_seq  = X_to_seq_feats(feat_extractor, X_test)
print(f"Sequence feature shape: {X_train_seq.shape}")

print("\n" + "=" * 50)
print("Training Model 2: CNN-LSTM")
print("=" * 50)

def build_lstm_seq_model(seq_shape, n_classes):
    inp = layers.Input(shape=seq_shape)
    x = layers.Bidirectional(layers.LSTM(128))(inp)
    x = layers.Dense(128, activation='relu')(x)
    out = layers.Dense(n_classes, activation='softmax')(x)
    m = models.Model(inp, out, name='cnn_lstm')
    m.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return m

lstm_model = build_lstm_seq_model((X_train_seq.shape[1], X_train_seq.shape[2]), num_classes)
history_lstm = lstm_model.fit(X_train_seq, y_train, validation_data=(X_test_seq, y_test),
                             epochs=EPOCHS, batch_size=BATCH_SIZE, verbose=2)

print("\n" + "=" * 50)
print("Training Model 3: CNN-GRU")
print("=" * 50)

def build_gru_seq_model(seq_shape, n_classes):
    inp = layers.Input(shape=seq_shape)
    x = layers.Bidirectional(layers.GRU(128))(inp)
    x = layers.Dense(128, activation='relu')(x)
    out = layers.Dense(n_classes, activation='softmax')(x)
    m = models.Model(inp, out, name='cnn_gru')
    m.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return m

gru_model = build_gru_seq_model((X_train_seq.shape[1], X_train_seq.shape[2]), num_classes)
history_gru = gru_model.fit(X_train_seq, y_train, validation_data=(X_test_seq, y_test),
                            epochs=EPOCHS, batch_size=BATCH_SIZE, verbose=2)

# ---------------------------
# Models 4,5,6: Transfer Learning

def build_transfer_model(base_model_name, input_shape, n_classes):
    print(f"Building Transfer Model: {base_model_name}")
    inp = layers.Input(shape=input_shape)

    if base_model_name == 'VGG16':
        base = tf.keras.applications.VGG16(include_top=False, weights='imagenet', input_tensor=inp)
        preprocess = tf.keras.applications.vgg16.preprocess_input
    elif base_model_name == 'ResNet50V2':
        base = tf.keras.applications.ResNet50V2(include_top=False, weights='imagenet', input_tensor=inp)
        preprocess = tf.keras.applications.resnet_v2.preprocess_input
    elif base_model_name == 'EfficientNetB0':
        base = tf.keras.applications.EfficientNetB0(include_top=False, weights='imagenet', input_tensor=inp)
        preprocess = tf.keras.applications.efficientnet.preprocess_input
    else:
        raise ValueError(f"Unknown model name: {base_model_name}")
    # Freezing the base model layers
    base.trainable = False

    x = base.output
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dense(256, activation='relu')(x)
    x = layers.Dropout(0.5)(x)
    out = layers.Dense(n_classes, activation='softmax')(x)
    m = models.Model(inputs=inp, outputs=out, name=f'{base_model_name}_transfer')
    m.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return m, preprocess

transfer_histories = {}
model_names = []
# Preprocessing 3-channel data
X_train_3_proc = {}
X_test_3_proc = {}
transfer_models = {}
for name in TRANSFER_MODELS:
    print("\n" + "=" * 50)
    print(f"Training Model: {name} Transfer (Model {4 + len(transfer_models)})")
    print("=" * 50)
    try:
        model, preprocess_fn = build_transfer_model(name, (IMG_H, IMG_W, 3), num_classes)
        model_names.append(model.name)
        transfer_models[name] = model
        X_train_3_proc[name] = preprocess_fn(X_train_3 * 255.0)
        X_test_3_proc[name] = preprocess_fn(X_test_3 * 255.0)

        history = model.fit(X_train_3_proc[name], y_train, validation_data=(X_test_3_proc[name], y_test),
                            epochs=EPOCHS, batch_size=BATCH_SIZE, verbose=2)
        transfer_histories[name] = history
    except Exception as e:
        print(f"Skipping {name} due to error: {e}")

# ---------------------------
# Final Results
print("\n" + "=" * 50)
print("FINAL MODEL EVALUATION")
print("=" * 50)
models_list = [('CNN Classifier', cnn_model, X_test, y_test),
              ('CNN-LSTM', lstm_model, X_test_seq, y_test),
              ('CNN-GRU', gru_model, X_test_seq, y_test),]
for name in TRANSFER_MODELS:
    if name in transfer_models:
        models_list.append((f'{name} Transfer', transfer_models[name], X_test_3_proc[name], y_test))

all_metrics = {}
for model_name, model, X_data, y_true in models_list:
    print(f"\n--- Evaluating {model_name} ---")
    # 1. Prediction and Accuracy
    y_pred_probs = model.predict(X_data, verbose=0)
    y_pred_cls = np.argmax(y_pred_probs, axis=1)
    test_accuracy = accuracy_score(y_true, y_pred_cls)
    print(f"Test Accuracy: {test_accuracy:.4f}")

    # 2. Detailed Metrics like Precision,Recall,F1-Score
    report = classification_report(y_true, y_pred_cls, target_names=class_names, zero_division=0, output_dict=True)
    all_metrics[model_name] = {
        'Accuracy': test_accuracy,
        'Precision (Macro)': report['macro avg']['precision'],
        'Recall (Macro)': report['macro avg']['recall'],
        'F1-Score (Macro)': report['macro avg']['f1-score'],
        'Classification Report': classification_report(y_true, y_pred_cls, target_names=class_names, zero_division=0)}

    # 3. Confusion Matrix
    cm = confusion_matrix(y_true, y_pred_cls)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)

    # Plotting the confusion matrix
    fig, ax = plt.subplots(figsize=(10, 10))
    disp.plot(cmap=plt.cm.Blues, ax=ax)
    plt.title(f'Confusion Matrix for {model_name}')
    plt.show()

# ---------------------------
# Accuracies Summary
print("\n" + "#" * 50)
print("ACCURACIES AND METRICS SUMMARY")
print("#" * 50)
print(f"Total samples used: {len(y_true) + len(y_train)}")
print(f"Number of classes (Top {TOP_K_WORDS} words): {num_classes}")
print("\n| Model Name | Test Accuracy | Macro Precision | Macro Recall | Macro F1-Score |")
print("|:---|:---:|:---:|:---:|:---:|")
best_accuracy = 0
best_model = ""
for model_name, metrics in all_metrics.items():
    acc = metrics['Accuracy']
    prec = metrics['Precision (Macro)']
    rec = metrics['Recall (Macro)']
    f1 = metrics['F1-Score (Macro)']
    print(f"| {model_name:<12} | {acc:.4f} | {prec:.4f} | {rec:.4f} | {f1:.4f} |")
    if acc > best_accuracy:
        best_accuracy = acc
        best_model = model_name

print("\n" + "-" * 50)
print(f"The best performing model is: {best_model} with Accuracy: {best_accuracy:.4f}")
print("-" * 50)
if best_model in all_metrics:
    print(f"\nDetailed Classification Report for {best_model}:\n")
    print(all_metrics[best_model]['Classification Report'])
# Out:
# Requirement already satisfied: kagglehub in /usr/local/lib/python3.12/dist-packages (0.3.13)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.12/dist-packages (2.19.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from kagglehub) (25.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from kagglehub) (6.0.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from kagglehub) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from kagglehub) (4.67.1)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.16.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (25.9.23)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (5.29.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.0.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.75.1)
# Requirement already satisfied: tensorboard~=2.19.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.10.0)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.15.1)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.5.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow) (0.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->kagglehub) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->kagglehub) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->kagglehub) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->kagglehub) (2025.10.5)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow) (3.9)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.5.0->tensorflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# Downloading and unzipping dataset...
# Downloading from https://www.kaggle.com/api/v1/datasets/download/naderabdalghani/iam-handwritten-forms-dataset?dataset_version_number=1...
# 100%|██████████| 4.31G/4.31G [02:29<00:00, 30.9MB/s]
# Extracting files...
# Dataset URL: https://www.kaggle.com/datasets/naderabdalghani/iam-handwritten-forms-dataset
# License(s): unknown
# Downloading iam-handwritten-forms-dataset.zip to /content
# 100% 4.29G/4.31G [00:21<00:00, 212MB/s]
# 100% 4.31G/4.31G [00:21<00:00, 213MB/s]
# Archive:  /content/iam-handwritten-forms-dataset.zip
#   inflating: /content/data/__notebook_source__.ipynb
#   inflating: /content/data/data/000/a01-000u.png
#   inflating: /content/data/data/000/a01-003u.png
#   inflating: /content/data/data/000/a01-007u.png
#   inflating: /content/data/data/000/a01-011u.png
#   inflating: /content/data/data/000/a01-014u.png
#   inflating: /content/data/data/000/a01-020u.png
#   inflating: /content/data/data/000/a01-026u.png
#   inflating: /content/data/data/000/a01-030u.png
#   inflating: /content/data/data/000/a01-043u.png
#   inflating: /content/data/data/000/a01-049u.png
#   inflating: /content/data/data/000/a01-049x.png
#   inflating: /content/data/data/000/a01-053u.png
#   inflating: /content/data/data/000/a01-058u.png
#   inflating: /content/data/data/000/a01-063u.png
#   inflating: /content/data/data/000/a01-068u.png
#   inflating: /content/data/data/000/a01-072u.png
#   inflating: /content/data/data/000/a01-077u.png
#   inflating: /content/data/data/000/a01-082u.png
#   inflating: /content/data/data/000/a01-087u.png
#   inflating: /content/data/data/000/a01-091u.png
#   inflating: /content/data/data/000/a01-096u.png
#   inflating: /content/data/data/000/a01-102u.png
#   inflating: /content/data/data/000/a01-107u.png
#   inflating: /content/data/data/000/a01-113u.png
#   inflating: /content/data/data/000/a01-117u.png
#   inflating: /content/data/data/000/a01-122u.png
#   inflating: /content/data/data/000/a01-128u.png
#   inflating: /content/data/data/000/a01-132u.png
#   inflating: /content/data/data/000/a01-132x.png
#   inflating: /content/data/data/000/a03-050.png
#   inflating: /content/data/data/000/a03-071.png
#   inflating: /content/data/data/000/a03-073.png
#   inflating: /content/data/data/000/a03-080.png
#   inflating: /content/data/data/000/a03-089.png
#   inflating: /content/data/data/000/a05-000.png
#   inflating: /content/data/data/000/a05-013.png
# Top 20 words: ['g06', 'a01', 'c03', 'h07', 'f07', 'b04', 'm04', 'c04', 'k04', 'l04', 'g07', 'n04', 'a02', 'e04', 'r06', 'b06', 'd06', 'a06', 'a05', 'g04']
# Pairs after filtering for top K words: 804
# --------------------------------------------------
# Loaded images shape: (804, 64, 256)
# Number of classes: 20
# Train/Test shapes (Grayscale): (643, 64, 256, 1) (161, 64, 256, 1)
# Train/Test shapes (3-Channel): (643, 64, 256, 3) (161, 64, 256, 3)
#
# ==================================================
# Training Model 1: CNN Classifier
# ==================================================
# Model: "cnn_classifier"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 64, 256, 1)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 64, 256, 32)    │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 32, 128, 32)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 32, 128, 64)    │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 16, 64, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 16, 64, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 128)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 20)             │         2,580 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 111,764 (436.58 KB)
#  Trainable params: 111,764 (436.58 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/6
# 21/21 - 9s - 450ms/step - accuracy: 0.1913 - loss: 2.8940 - val_accuracy: 0.1988 - val_loss: 2.8361
# Epoch 2/6
# 21/21 - 0s - 23ms/step - accuracy: 0.1960 - loss: 2.8427 - val_accuracy: 0.1988 - val_loss: 2.8259
# Epoch 3/6
# 21/21 - 1s - 26ms/step - accuracy: 0.1960 - loss: 2.8411 - val_accuracy: 0.1988 - val_loss: 2.8256
# Epoch 4/6
# 21/21 - 1s - 26ms/step - accuracy: 0.1960 - loss: 2.8406 - val_accuracy: 0.1988 - val_loss: 2.8253
# Epoch 5/6
# 21/21 - 0s - 22ms/step - accuracy: 0.1960 - loss: 2.8394 - val_accuracy: 0.1988 - val_loss: 2.8255
# Epoch 6/6
# 21/21 - 0s - 19ms/step - accuracy: 0.1960 - loss: 2.8379 - val_accuracy: 0.1988 - val_loss: 2.8253
# Extracting features...
# Extracting features...
# Sequence feature shape: (643, 256, 1024)
#
# ==================================================
# Training Model 2: CNN-LSTM
# ==================================================
# Epoch 1/6
# 21/21 - 7s - 316ms/step - accuracy: 0.1742 - loss: 2.9016 - val_accuracy: 0.1988 - val_loss: 2.8396
# Epoch 2/6
# 21/21 - 1s - 57ms/step - accuracy: 0.1960 - loss: 2.8594 - val_accuracy: 0.1988 - val_loss: 2.8268
# Epoch 3/6
# 21/21 - 1s - 54ms/step - accuracy: 0.1960 - loss: 2.8401 - val_accuracy: 0.1988 - val_loss: 2.8253
# Epoch 4/6
# 21/21 - 1s - 54ms/step - accuracy: 0.1960 - loss: 2.8387 - val_accuracy: 0.1988 - val_loss: 2.8247
# Epoch 5/6
# 21/21 - 1s - 59ms/step - accuracy: 0.1960 - loss: 2.8375 - val_accuracy: 0.1988 - val_loss: 2.8242
# Epoch 6/6
# 21/21 - 1s - 61ms/step - accuracy: 0.1960 - loss: 2.8364 - val_accuracy: 0.1988 - val_loss: 2.8231
#
# ==================================================
# Training Model 3: CNN-GRU
# ==================================================
# Epoch 1/6
# 21/21 - 4s - 180ms/step - accuracy: 0.1788 - loss: 2.8991 - val_accuracy: 0.1988 - val_loss: 2.8441
# Epoch 2/6
# 21/21 - 1s - 65ms/step - accuracy: 0.1960 - loss: 2.8737 - val_accuracy: 0.1988 - val_loss: 2.8263
# Epoch 3/6
# 21/21 - 1s - 51ms/step - accuracy: 0.1960 - loss: 2.8482 - val_accuracy: 0.1988 - val_loss: 2.8283
# Epoch 4/6
# 21/21 - 1s - 52ms/step - accuracy: 0.1960 - loss: 2.8420 - val_accuracy: 0.1988 - val_loss: 2.8280
# Epoch 5/6
# 21/21 - 1s - 60ms/step - accuracy: 0.1960 - loss: 2.8402 - val_accuracy: 0.1988 - val_loss: 2.8303
# Epoch 6/6
# 21/21 - 1s - 51ms/step - accuracy: 0.1960 - loss: 2.8380 - val_accuracy: 0.1988 - val_loss: 2.8319
#
# ==================================================
# Training Model: VGG16 Transfer (Model 4)
# ==================================================
# Building Transfer Model: VGG16
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step
# Epoch 1/6
# 21/21 - 20s - 958ms/step - accuracy: 0.0638 - loss: 13.7184 - val_accuracy: 0.2360 - val_loss: 3.9389
# Epoch 2/6
# 21/21 - 1s - 71ms/step - accuracy: 0.1415 - loss: 5.5752 - val_accuracy: 0.3416 - val_loss: 2.2697
# Epoch 3/6
# 21/21 - 2s - 71ms/step - accuracy: 0.2986 - loss: 2.5833 - val_accuracy: 0.3789 - val_loss: 2.0975
# Epoch 4/6
# 21/21 - 1s - 71ms/step - accuracy: 0.3515 - loss: 2.2166 - val_accuracy: 0.4658 - val_loss: 1.9287
# Epoch 5/6
# 21/21 - 2s - 88ms/step - accuracy: 0.3888 - loss: 2.1055 - val_accuracy: 0.4845 - val_loss: 1.8103
# Epoch 6/6
# 21/21 - 2s - 73ms/step - accuracy: 0.4261 - loss: 1.9300 - val_accuracy: 0.4720 - val_loss: 1.7085
#
# ==================================================
# Training Model: ResNet50V2 Transfer (Model 5)
# ==================================================
# Building Transfer Model: ResNet50V2
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94668760/94668760 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step
# Epoch 1/6
# 21/21 - 24s - 1s/step - accuracy: 0.2022 - loss: 2.9704 - val_accuracy: 0.3416 - val_loss: 2.4530
# Epoch 2/6
# 21/21 - 1s - 35ms/step - accuracy: 0.3219 - loss: 2.3990 - val_accuracy: 0.3416 - val_loss: 2.2263
# Epoch 3/6
# 21/21 - 1s - 34ms/step - accuracy: 0.3655 - loss: 2.1358 - val_accuracy: 0.3540 - val_loss: 2.0846
# Epoch 4/6
# 21/21 - 1s - 34ms/step - accuracy: 0.4323 - loss: 1.9201 - val_accuracy: 0.3975 - val_loss: 1.9892
# Epoch 5/6
# 21/21 - 1s - 34ms/step - accuracy: 0.4821 - loss: 1.7423 - val_accuracy: 0.4224 - val_loss: 1.8943
# Epoch 6/6
# 21/21 - 1s - 43ms/step - accuracy: 0.5257 - loss: 1.5968 - val_accuracy: 0.4410 - val_loss: 1.8342
#
# ==================================================
# Training Model: EfficientNetB0 Transfer (Model 6)
# ==================================================
# Building Transfer Model: EfficientNetB0
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Epoch 1/6
# 21/21 - 59s - 3s/step - accuracy: 0.1944 - loss: 2.9082 - val_accuracy: 0.2733 - val_loss: 2.6603
# Epoch 2/6
# 21/21 - 1s - 26ms/step - accuracy: 0.2473 - loss: 2.6535 - val_accuracy: 0.3416 - val_loss: 2.5195
# Epoch 3/6
# 21/21 - 0s - 22ms/step - accuracy: 0.2613 - loss: 2.5116 - val_accuracy: 0.3292 - val_loss: 2.4057
# Epoch 4/6
# 21/21 - 0s - 22ms/step - accuracy: 0.3017 - loss: 2.4555 - val_accuracy: 0.3727 - val_loss: 2.3566
# Epoch 5/6
# 21/21 - 0s - 21ms/step - accuracy: 0.2893 - loss: 2.3982 - val_accuracy: 0.3230 - val_loss: 2.2785
# Epoch 6/6
# 21/21 - 0s - 22ms/step - accuracy: 0.3281 - loss: 2.2587 - val_accuracy: 0.3602 - val_loss: 2.1996
#
# ==================================================
# FINAL MODEL EVALUATION
# ==================================================
#
# --- Evaluating CNN Classifier ---
# Test Accuracy: 0.1988
# --- Evaluating CNN-LSTM ---
# Test Accuracy: 0.1988
# --- Evaluating CNN-GRU ---
# WARNING:tensorflow:5 out of the last 13 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7c273f325bc0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Test Accuracy: 0.1988
# --- Evaluating VGG16 Transfer ---
# WARNING:tensorflow:5 out of the last 13 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7c273c76cd60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Test Accuracy: 0.4720
# --- Evaluating ResNet50V2 Transfer ---
# Test Accuracy: 0.4410
# --- Evaluating EfficientNetB0 Transfer ---
# Test Accuracy: 0.3602
# ##################################################
# ACCURACIES AND METRICS SUMMARY
# ##################################################
# Total samples used: 804
# Number of classes (Top 20 words): 20
#
# | Model Name | Test Accuracy | Macro Precision | Macro Recall | Macro F1-Score |
# |:---|:---:|:---:|:---:|:---:|
# | CNN Classifier | 0.1988 | 0.0099 | 0.0500 | 0.0166 |
# | CNN-LSTM     | 0.1988 | 0.0099 | 0.0500 | 0.0166 |
# | CNN-GRU      | 0.1988 | 0.0099 | 0.0500 | 0.0166 |
# | VGG16 Transfer | 0.4720 | 0.3875 | 0.3299 | 0.3081 |
# | ResNet50V2 Transfer | 0.4410 | 0.3677 | 0.3307 | 0.3037 |
# | EfficientNetB0 Transfer | 0.3602 | 0.1812 | 0.1857 | 0.1353 |
#
# --------------------------------------------------
# The best performing model is: VGG16 Transfer with Accuracy: 0.4720
# --------------------------------------------------
#
# Detailed Classification Report for VGG16 Transfer:
#
#               precision    recall  f1-score   support
#
#          a01       0.50      0.62      0.55        13
#          a02       0.00      0.00      0.00         6
#          a05       0.57      0.80      0.67         5
#          a06       0.00      0.00      0.00         5
#          b04       0.50      0.33      0.40         6
#          b06       1.00      0.17      0.29         6
#          c03       0.52      0.92      0.67        12
#          c04       0.00      0.00      0.00         6
#          d06       0.17      0.17      0.17         6
#          e04       0.67      0.33      0.44         6
#          f07       0.16      0.38      0.22         8
#          g04       0.50      0.20      0.29         5
#          g06       0.63      0.97      0.77        32
#          g07       0.00      0.00      0.00         6
#          h07       0.56      0.56      0.56         9
#          k04       0.67      0.33      0.44         6
#          l04       1.00      0.17      0.29         6
#          m04       0.31      0.67      0.42         6
#          n04       0.00      0.00      0.00         6
#          r06       0.00      0.00      0.00         6
#
#     accuracy                           0.47       161
#    macro avg       0.39      0.33      0.31       161
# weighted avg       0.44      0.47      0.41       161
